# %%
import pandas as pd
import zarr
import allel
import numpy as np
import json

# %% [markdown]
# # Import Data:

# %% [markdown]
# ## Chromosome 22 Zarr Data File:
#
# - Below the Gene data from the Chromosome 22 zarr file is imported and the unique genes across GENE1 and GENE2 are combined to create one list of unique genes.

# %%
zarr_path = '../website/data/FINAL_30x_GR38_NoBiIndel.zarr'
callset = zarr.open_group(zarr_path, mode='r')
callset
# Out:
# <zarr.hierarchy.Group '/' read-only>

# %%
variants = allel.VariantChunkedTable(callset['22']['variants'], 
                                     names=['GENE1', 'GENE2'])

# %%
# Create a dataframe from the Variant Chunked Table:
g_df = pd.DataFrame(variants['GENE1'], columns = ['GENE1'])
g_df2 = pd.DataFrame(variants['GENE2'], columns = ['GENE2'])

# Join the two dataframes:
gene_zarr_data = pd.concat([g_df, g_df2], axis=1)

# %%
# Get a list of the unique genes across both Gene1 and Gene2 columns:
column_values = gene_zarr_data[["GENE1", "GENE2"]].values.ravel()

unique_values =  list(pd.unique(column_values))
unique_values.remove('None')
unique_values.remove('nan')

# %%
len(unique_values)
# Out:
# 816

# %%
uniq_genes = pd.DataFrame(unique_values, columns = ['GENE'])
uniq_genes.head()
# Out:
#            GENE
# 0  LOC105379418
# 1        FRG1FP
# 2  LOC107984037
# 3  LOC102723769
# 4  LOC107987323

# %%
uniq_genes[uniq_genes['GENE']== 'ABHD17AP5']
# Out:
# Empty DataFrame
# Columns: [GENE]
# Index: []

# %% [markdown]
# ## Aliases Data:
# - Genes and aliases data was downloaded from the following source: https://www.ncbi.nlm.nih.gov/gene/

# %%
# Please update to include path to downloaded data:
gene_alias = pd.read_csv(path_to_gene_alias_data)

# Dropping any rows with nan values in Aliases column:
gene_alias = gene_alias.dropna(how='any',
                    subset=['Aliases']).rename(columns={"Symbol": "GENE"})

# Retaining just Gene and Aliases columns:
gene_alias = gene_alias[['GENE', 'Aliases']]

# %%
gene_alias.head()
# Out:
#         GENE                                     Aliases
# 0     A4GALT  A14GALT1, Gb3S, P(k), P1, P1PK, PK, A4GALT
# 1    ABCD1P4                                    ALD22Q11
# 2  ABHD17AP4                         FAM108A5, FAM108A5P
# 3  ABHD17AP5                         FAM108A6, FAM108A6P
# 5       ACO2          ACONM, HEL-S-284, ICRD, OCA8, OPA9

# %% [markdown]
# # Merge the Dataframes:
#
# - Here we are comparing the aliases data to the genes that are present in our website data.
# - We are merging the two dataframes to obtain the aliases for those genes.

# %%
merged_gene_data = pd.merge(uniq_genes, gene_alias,  how='left', on = ['GENE'])
merged_gene_data.head()
# Out:
#            GENE Aliases
# 0  LOC105379418     NaN
# 1        FRG1FP     NaN
# 2  LOC107984037     NaN
# 3  LOC102723769     NaN
# 4  LOC107987323     NaN

# %%
# Again dropping any rows with nan values in Aliases column:
genes_w_aliases = merged_gene_data.dropna(how='any', subset=['Aliases'])
genes_w_aliases.head()
# Out:
#          GENE                         Aliases
# 7      OR11H1                 OR11H12, OR22-1
# 9       POTEH  A26C3, ACTBL1, CT104.7, POTE22
# 10  POTEH-AS1                    LA16c-3G11.5
# 11      PSLNR                   LA16c-83F12.6
# 15     CCT8L2                           CESK1

# %%
len(genes_w_aliases)
# Out:
# 472

# %% [markdown]
# - There are 816 unique genes in our Chromosome 22 data, 472 of these have aliases as per the NCBI data.

# %%
g_list = list(genes_w_aliases['GENE'])
a_list = list(genes_w_aliases['Aliases'])

gene_alias_dict = dict(zip(g_list, a_list))

# %%
gene_alias_dict
# Out:
# {'OR11H1': 'OR11H12, OR22-1',
#  'POTEH': 'A26C3, ACTBL1, CT104.7, POTE22',
#  'POTEH-AS1': 'LA16c-3G11.5',
#  'PSLNR': 'LA16c-83F12.6',
#  'CCT8L2': 'CESK1',
#  'TPTEP1': 'psiTPTE22',
#  'ANKRD62P1-PARP4P3': 'VWFP1-ANKRD62P1-PARP4P3',
#  'XKR3': 'XRG3, XTES',
#  'HSFY1P1': 'CECR8, HSFYL1, HSFYP1, NCRNA00016',
#  'CECR7': 'SAHL1',
#  'IL17RA': 'CANDF5, CD217, CDw217, IL-17RA, IL17R, IMD51, hIL-17R',
#  'TMEM121B': 'CECR6',
#  'HDHD5': 'CECR5',
#  'HDHD5-AS1': 'CECR4, CECR5-AS1, NCRNA00017',
#  'ADA2': 'ADGF, CECR1, IDGFL, PAN, SNEDS, VAIHS',
#  'SLC25A18': 'GC2',
#  'ATP6V1E1': 'ARCL2C, ATP6E, ATP6E2, ATP6V1E, P31, Vma4',
#  'BCL2L13': 'BCL-RAMBO, Bcl2-L-13, MIL1',
#  'BID': 'FP497',
#  'MIR3198-1': 'MIR3198, mir-3198-1',
#  'LINC00528': 'C22orf37',
#  'MICAL3': 'MICAL-3',
#  'MIR648': 'MIRN648, hsa-mir-648',
#  'PEX26': 'PBD7A, PBD7BM1T, Pex26pM1T, PEX26',
#  'TUBA8': 'CDCBM8, TUBAL2',
#  'USP18': 'ISG43, PTORCH2, UBP43',
#  'FAM230D': 'LINC02592',
#  'FAM230J': 'LINC01660',
#  'FAM230A': 'DGCR15',
#  'GGTLC3': 'GGT',
#  'RIMBP3': 'RIM-BP3, RIM-BP3.1, RIM-BP3.A.1, RIMBP3A, RIMBP3',
#  'FAM230E': 'LINC01662',
#  'GGT3P': 'GGT3',
#  'FAM230F': 'LINC01663',
#  'PRODH': 'HSPOX2, PIG6, POX1, PRODH2, TP53I6, PRODH',
#  'DGCR5': 'DGCR10, DGCR9, DGS-A, DGS-B, LINC00037, NCRNA00037, POM121L5P',
#  'DGCR2': 'DGS-C, IDD, LAN, SEZ-12',
#  'DGCR11': 'DGS-D',
#  'ESS2': 'DGCR13, DGCR14, DGS-H, DGS-I, DGSH, DGSI, ES2, ESS-2, Es2el, bis1',
#  'TSSK2': 'DGS-G, SPOGA2, STK22B, TSK2',
#  'GSC2': 'GSCL',
#  'SLC25A1': 'CMS23, CTP, D2L2AD, SEA, SLC20A3',
#  'CLTCL1': 'CHC22, CLH22, CLTCL, CLTD',
#  'HIRA': 'DGCR1, TUP1, TUPLE1',
#  'MRPL40': 'L40mt, MRP-L22, MRP-L40, MRPL22, NLVCF, URIM',
#  'UFD1': 'UFD1L',
#  'CDC45': 'CDC45LL2, MGORS7, PORC-PI-1, CDC45',
#  'CLDN5': 'AWAL, BEC1, CPETRL1, TMDVCF, TMVCF',
#  'SEPTIN5': 'CDCREL, CDCREL-1, CDCREL1, H5, HCDCREL-1, PNUTL1, SEPT5',
#  'SEPT5-GP1BB': 'GP1BB, GPIb-beta, GPIbB',
#  'GP1BB': 'BDPLT1, BS, CD42C, GPIBB, GPIbbeta',
#  'TBX1': 'CAFS, CATCH22, CTHM, DGCR, DGS, DORVC, TGA, VCF, VCFS, TBX1',
#  'GNB1L': 'DGCRK3, FKSG1, GY2, WDR14, WDVCF',
#  'RTL10': 'BOP, C22orf29',
#  'TXNRD2': 'GCCD5, SELZ, TR, TR-BETA, TR3, TRXR2',
#  'COMT': 'HEL-S-98n',
#  'TANGO2': 'C22orf25, MECRCN',
#  'MIR185': 'MIRN185, miR-185',
#  'DGCR8': 'C22orf12, DGCRK6, Gy1, pasha',
#  'MIR1306': 'MIRN1306, hsa-mir-1306, mir-1306',
#  'TRMT2A': 'HTF9C',
#  'RANBP1': 'HTF9A',
#  'ZDHHC8': 'DHHC8, ZDHHCL1, ZNF378',
#  'LINC02891': 'lnc-RTN4R-1',
#  'RTN4R': 'NGR, NOGOR',
#  'DGCR6L': 'DGCR6',
#  'ZNF74': 'COS52, ZFP520, ZNF520, hZNF7',
#  'SCARF2': 'NSR1, SREC-II, SREC2, SRECRP-1, VDEGS',
#  'KLHL22': 'KELCHL',
#  'MED15': 'ARC105, CAG7A, CTG7A, PCQAP, TIG-1, TIG1, TNRC7',
#  'TMEM191A': 'TMEM191AP',
#  'PI4KA': 'GIDID2, PI4K-ALPHA, PIK4CA, PMGYCHA, SPG84, pi4K230',
#  'SERPIND1': 'D22S673, HC2, HCF2, HCII, HLS2, LS2, THPH10',
#  'SNAP29': 'CEDNIK, SNAP-29',
#  'AIFM3': 'AIFL',
#  'LZTR1': 'BTBD29, LZTR-1, NS10, NS2, SWNTS2',
#  'P2RX6': 'P2RXL1, P2X6, P2XM',
#  'SLC7A4': 'CAT-4, CAT4, HCAT3, VH',
#  'MIR649': 'MIRN649, hsa-mir-649',
#  'BCRP2': 'BCR-2, BCR2, BCRL2',
#  'POM121L8P': 'DKFZp434K191',
#  'RIMBP3B': 'RIM-BP3.2, RIM-BP3.B, RIMBP3.2',
#  'HIC2': 'HRG22, ZBTB30, ZNF907',
#  'RIMBP3C': 'RIM-BP3.3, RIMBP3.3',
#  'UBE2L3': 'E2-F1, L-UBC, UBCH7, UbcM4',
#  'MIR130B': 'MIRN130B, mir-130b',
#  'PPIL2': 'CYC4, CYP60, Cyp-60, UBOX7, hCyP-60',
#  'YPEL1': 'FKSG3',
#  'MAPK1': 'ERK, ERK-2, ERK2, ERT1, MAPK2, NS13, P42MAPK, PRKM1, PRKM2, p38, p40, p41, p41mapk, p42-MAPK',
#  'PPM1F': 'CAMKP, CaMKPase, FEM-2, POPX2, hFEM-2',
#  'TOP3B': 'TOP3B1',
#  'PRAMENP': 'PRAMEF24P, PRAMEL',
#  'VPREB1': 'CD179a, IGI, IGVPB, VPREB',
#  'BMS1P20': 'IGL, IGLV, IGLV1',
#  'ZNF280B': "5'OY11.1, D87009.C22.3, SUHW2, ZNF279, ZNF632",
#  'ZNF280A': "3'OY11.1, SUHW1, ZNF280, ZNF636",
#  'PRAME': 'CT130, MAPE, OIP-4, OIP4',
#  'POM121L1P': 'POM121L1',
#  'GGTLC2': 'GGTL4',
#  'MIR650': 'MIRN650, hsa-mir-650',
#  'IGLL5': 'IGL, IGLV, VL-MAR',
#  'RSPH14': 'RTDR1',
#  'GNAZ': 'HG1H, gz-alpha',
#  'BCR': 'ALL1, CML, D22S11, D22S662, PHL, BCR',
#  'FBXW4P1': 'FBW3, FBXW3, SHFM3P1',
#  'ZDHHC8P1': 'ZDHHC8P',
#  'FAM230I': 'LINC01658',
#  'IGLL1': '14.1, AGM2, CD179b, IGL1, IGL5, IGLJ14.1, IGLL, IGO, IGVPB, VPREB2',
#  'DRICH1': 'C22orf43, KB-208E9.1',
#  'RGL4': 'Rgr',
#  'ZNF70': 'Cos17',
#  'VPREB3': '8HS20, N27C7-2',
#  'C22orf15': 'N27C7-3',
#  'CHCHD10': 'C22orf16, FTDALS2, IMMD, MIX17A, N27C7-4, SMAJ',
#  'MMP11': 'SL-3, ST3, STMY3',
#  'SMARCB1': 'BAF47, CSS3, INI-1, INI1, MRD15, PPP1R144, RDT, RTPS1, SNF5, SNF5L1, SWNTS1, Sfh1p, Snr1, hSNFS',
#  'DERL3': 'C22orf14, IZP6, LLN2, derlin-3',
#  'SLC2A11': 'GLUT10, GLUT11',
#  'MIF-AS1': 'MIF-AS',
#  'MIF': 'GIF, GLIF, MMIF',
#  'GSTT2B': 'GSTT2P',
#  'DDTL': 'DDT, KB-226F1.2',
#  'DDT': 'D-DT, DDCT, MIF-2, MIF2',
#  'GSTT4': 'GSTTP1, HS322B1A',
#  'CABIN1': 'CAIN, KB-318B8.7, PPP3IN',
#  'SUSD2': 'BK65A6.2, W5C5',
#  'GGT5': 'GGL, GGT 5, GGT-REL, GGTLA1',
#  'POM121L9P': 'DKFZP434P211, UNQ2565',
#  'SPECC1L': 'CYTSA, GBBB2, OBLFC1, TBHS, TBHS1',
#  'ADORA2A': 'A2aR, ADORA2, RDC8',
#  'ADORA2A-AS1': 'C22orf45',
#  'UPB1': 'BUP1',
#  'GUCD1': 'C22orf13, LLN4',
#  'SNRPD3': 'SMD3, Sm-D3',
#  'GGT1': 'CD224, D22S672, D22S732, GGT, GGT 1, GGTD, GTG',
#  'LRRC75B': 'C22orf36, FAM211B',
#  'BCRP3': 'BCR3, BCRL3, BCRL6',
#  'PIWIL3': 'HIWI3',
#  'SGSM1': 'RUTBC2',
#  'CRYBB3': 'CATCN2, CRYB3, CTRCT22',
#  'CRYBB2': 'CCA2, CRYB2, CRYB2A, CTRCT3, D22S665',
#  'IGLL3P': '16.1, IGLL3',
#  'CRYBB2P1': 'CRYB2B',
#  'MIR6817': 'hsa-mir-6817',
#  'GRK3': 'ADRBK2, BARK2',
#  'MYO18B': 'KFS4',
#  'SEZ6L': 'dJ268D13.1',
#  'HPS4': 'BLOC3S2, LE',
#  'SRRD': 'HC/HCC, SRR1L',
#  'TFIP11': 'NTR1, STIP, STIP-1, Spp382, TIP39, bK445C9.6',
#  'TPST2': 'TANGO13B, TPST-2',
#  'MIR548J': 'MIRN548J, hsa-mir-548j',
#  'CRYBB1': 'CATCN3, CTRCT17',
#  'CRYBA4': 'CTRCT23, CYRBA4, MCOPCT4',
#  'MIAT': 'C22orf35, GOMAFU, LINC00066, NCRNA00066, RNCR2, lncRNA-MIAT',
#  'MN1': 'CEBALID, MGCR, MGCR1, MGCR1-PEN, dJ353E16.2',
#  'PITPNB': 'PI-TP-beta, PtdInsTP, VIB1B',
#  'TTC28-AS1': 'TTC28-AS, TTC28AS, dJ353E16.2',
#  'MIR3199-2': 'mir-3199-2',
#  'TTC28': 'TPRBK',
#  'MIR5739': 'hsa-mir-5739',
#  'CHEK2': 'CDS1, CHK2, HuCds1, LFS2, PP1425, RAD53, hCds1',
#  'HSCB': 'DNAJC20, HSC20, JAC1, SIDBA5',
#  'CCDC117': 'dJ366L4.1',
#  'XBP1': 'TREB-5, TREB5, XBP-1, XBP2',
#  'ZNRF3': 'BK747E2.3, RNF203',
#  'C22orf31': 'HS747E2A, bK747E2.1',
#  'KREMEN1': 'ECTD13, KREMEN, KRM1',
#  'EMID1': 'EMI5, EMU1',
#  'RHBDD3': 'C22orf3, HS984G1A, PTAG',
#  'EWSR1': 'EWS, EWS-FLI1, bK984G1.4',
#  'GAS2L1': 'GAR22',
#  'RASL10A': 'RRP22',
#  'AP1B1': 'ADTB1, AP105A, BAM22, CLAPB2, KIDAR',
#  'RFPL1': 'RNF78',
#  'RFPL1S': 'NCRNA00006, RFPL1-AS, RFPL1-AS1, RFPL1AS',
#  'NEFH': 'CMT2CC, NFH',
#  'THOC5': 'C22orf19, Fmip, KIAA0983, PK1.3',
#  'NF2': 'ACN, BANF, SCH, merlin-1',
#  'CABP7': 'CALN2',
#  'ZMAT5': 'SNRNP20, U11/U12-20K, ZC3H19',
#  'UQCR10': 'HSPC051, HSPC119, HSPC151, QCR9, UCCR7.2, UCRC',
#  'ASCC2': 'ASC1p100, p100',
#  'MTMR3': 'FYVE-DSP1, ZFYVE10',
#  'MIR6818': 'hsa-mir-6818',
#  'HORMAD2-AS1': 'MTMR3-AS1',
#  'HORMAD2': 'CT46.2',
#  'LIF-AS1': 'Lnc-LIF-AS',
#  'LIF': 'CDF, DIA, HILDA, MLPLI',
#  'CASTOR1': 'GATSL3',
#  'TBC1D10A': 'EPI64, TBC1D10, dJ130H16.1, dJ130H16.2',
#  'SF3A1': 'PRP21, PRPF21, SAP11420, SF3A1',
#  'SEC14L2': 'C22orf6, SPF, TAP, TAP1',
#  'MTFP1': 'HSPC242, MTP18',
#  'SEC14L3': 'TAP2',
#  'SEC14L4': 'TAP3',
#  'GAL3ST1': 'CST',
#  'TCN2': 'D22S676, D22S750, II, TC, TC II, TC-2, TC2, TCII',
#  'DUSP18': 'DSP18, DUSP20, LMWDSP20',
#  'OSBP2': 'HLM, ORP-4, ORP4, OSBPL1, OSBPL4',
#  'MIR3200': 'mir-3200',
#  'MORC2-AS1': 'C22orf27, NCRNA00325',
#  'MORC2': 'CMT2Z, DIGFAN, ZCW3, ZCWCC1',
#  'TUG1': 'LINC00080, NCRNA00080, TI-227H',
#  'SELENOM': 'SELM, SEPM',
#  'INPP5J': 'INPP5, PIB5PA, PIPP',
#  'PLA2G3': 'GIII-SPLA2, SPLA2III, sPLA2-III',
#  'MIR3928': 'mir-3928',
#  'PIK3IP1': 'HGFL, TrIP, hHGFL(S)',
#  'PATZ1': 'MAZR, PATZ, RIAZ, ZBTB19, ZNF278, ZSG, dJ400N23',
#  'PIK3IP1-DT': 'PIK3IP1-AS1',
#  'DRG1': 'NEDD3',
#  'EIF4ENIF1': '4E-T, Clast4',
#  'SFI1': 'PISD, PPP1R139, hSfi1p',
#  'PISD': 'DJ858B16, LIBF, PSD, PSDC, PSSC, dJ858B16.2',
#  'MIR7109': 'hsa-mir-7109',
#  'PRR14L': 'C22orf30',
#  'DEPDC5': 'DEP.5, FFEVF, FFEVF1',
#  'YWHAH-AS1': 'C22orf24, HSN44A4A',
#  'YWHAH': 'YWHA1',
#  'SLC5A1': 'D22S675, NAGT, SGLT1',
#  'AP1B1P1': 'ADTB1L1, dJ127L4.2',
#  'C22orf42': 'dJ90G24.6',
#  'RFPL2': 'RNF79',
#  'SLC5A4': 'DJ90G24.4, SAAT1, SGLT3',
#  'RFPL3': 'RNF120',
#  'RFPL3S': 'NCRNA00005, RFPL3-AS, RFPL3-AS1, RFPL3ANT, RFPL3AS',
#  'RTCB': 'C22orf28, DJ149A16.6, FAAP, HSPC117',
#  'BPIFC': 'BPIL2',
#  'FBXO7': 'FBX, FBX07, FBX7, PARK15, PKPS',
#  'SYN3-AS1': 'LL22NC03-104C7.1',
#  'TIMP3': 'HSMRK222, K222, K222TA2, SFD',
#  'LARGE1': 'LARGE, MDC1D, MDDGA6, MDDGB6',
#  'LINC01643': 'LL22NC03-86D4.1',
#  'LINC02885': 'ISX-AS1',
#  'ISX': 'Pix-1, RAXLX',
#  'HMGXB4': 'HMG2L1, HMGBCG, P53N, THC211630',
#  'TOM1': 'IMD85',
#  'MIR3909': 'mir-3909',
#  'HMOX1': 'HMOX1D, HO-1, HSP32, bK286B10',
#  'MCM5': 'CDC46, MGORS8, P1-CDC46',
#  'RASD2': 'Rhes, TEM2',
#  'MB': 'PVALB',
#  'APOL6': 'APOL-VI, APOLVI',
#  'APOL5': 'APOL-V, APOLV',
#  'RBFOX2': 'FOX2, Fox-2, HNRBP2, HRNBP2, RBM9, RTA, dJ106I20.3, fxh',
#  'APOL3': 'APOLIII, CG121, CG12_1, apoL-III',
#  'APOL4': 'APOL-IV, APOLIV',
#  'APOL2': 'APOL-II, APOL3',
#  'APOL1': 'APO-L, APOL, APOL-I, FSGS4',
#  'MYH9': 'BDPLT6, DFNA17, EPSTS, FTNS, MATINS, MHA, NMHC-II-A, NMMHC-IIA, NMMHCA',
#  'MIR6819': 'hsa-mir-6819',
#  'TXN2': 'COXPD29, MT-TRX, MTRX, TRX2, TXN',
#  'FOXRED2': 'ERFAD',
#  'EIF3D': 'EIF3S7, eIF3-p66, eIF3-zeta',
#  'CACNG2': 'MRD10',
#  'IFT27': 'BBS19, FAP156, RABL4, RAYL',
#  'PVALB': 'D22S749',
#  'NCF4': 'CGD3, NCF, P40PHOX, SH3PXD4',
#  'CSF2RB': 'CD131, CDw131, IL3RB, IL5RB, SMDP5, betaGMR',
#  'TEX33': 'C22orf33, EAN57, cE81G9.2',
#  'TST': 'RDS',
#  'MPST': 'MST, TST2, TUM1',
#  'TMPRSS6': 'IRIDA, MT2',
#  'IL2RB': 'CD122, IL15RB, IMD63, P70-75',
#  'C1QTNF6': 'CTFP6, CTRP6, ZACRP6',
#  'SSTR3': 'SS-3-R, SS3-R, SS3R, SSR-28',
#  'RAC2': 'EN-7, Gx, HSPC022, IMD73A, IMD73B, IMD73C, p21-Rac2',
#  'CYTH4': 'CYT4, DJ63G5.1, PSCD4, cytohesin-4',
#  'ELFN2': 'LRRC62, PPP1R29',
#  'CARD10': 'BIMP1, CARMA3, IMD89',
#  'CDC42EP1': 'BORG5, CEP1, MSE55',
#  'LGALS2': 'HL14',
#  'SH3BP1': 'ARHGAP43',
#  'PDXP': 'CIN, PLP, dJ37E16.5',
#  'LGALS1': 'GAL1, GBP',
#  'NOL12': 'Nop25, dJ37E16.7',
#  'TRIOBP': 'DFNB28, HRIHFB2122, TAP68, TARA, dJ37E16.4',
#  'H1-0': 'H1.0, H10, H1F0, H1FV',
#  'GCAT': 'KBL',
#  'ANKRD54': 'LIAR',
#  'MIR658': 'MIRN658, hsa-mir-658',
#  'MIR659': 'MIRN659, hsa-mir-659, mir-659',
#  'EIF3L': 'EIF3EIP, EIF3S11, EIF3S6IP, HSPC021, HSPC025, MSTP005',
#  'MICALL1': 'MICAL-L1, MIRAB13',
#  'C22orf23': 'EVG1, dJ1039K5.6',
#  'POLR2F': 'HRBP14.4, POLRF, RPABC14.4, RPABC2, RPB14.4, RPB6, RPC15',
#  'SOX10': 'DOM, PCWH, SOX-10, WS2E, WS4, WS4C',
#  'PICK1': 'PICK, PRKCABP',
#  'SLC16A8': 'MCT3, REMP',
#  'PLA2G6': 'CaI-PLA2, GVI, INAD1, IPLA2-VIA, NBIA2, NBIA2A, NBIA2B, PARK14, PLA2, PNPLA9, iPLA2, iPLA2beta',
#  'MAFF': 'U-MAF, hMafF',
#  'TMEM184B': 'C22orf5, FM08, HS5O6A, HSPC256',
#  'CSNK1E': 'CKIe, CKIepsilon, HCKIE',
#  'TPTEP2-CSNK1E': 'LOC400927-CSNK1E',
#  'TPTEP2': 'Z98749.2',
#  'KCNJ4': 'HIR, HIRK2, HRK1, IRK-3, IRK3, Kir2.3',
#  'KDELR3': 'ERD2L3',
#  'DDX17': 'P72, RH70',
#  'DMC1': 'DMC1H, LIM15, dJ199H16.1',
#  'CBY1': 'C22orf2, CBY, Chibby1, HS508I15A, PGEA1, PIGEA-14, PIGEA14, arb1',
#  'TOMM22': '1C9-2, MST065, MSTP065, TOM22',
#  'JOSD1': 'dJ508I15.2',
#  'GTPBP1': 'GP-1, GP1, HSPC018',
#  'SUN2': 'UNC84B, rab5IP',
#  'DNAL4': 'MRMV3, PIG27',
#  'NPTXR': 'NPR',
#  'APOBEC3A': 'A3A, ARP3, PHRBN, bK150C2.1',
#  'APOBEC3B': 'A3B, APOBEC1L, ARCD3, ARP4, DJ742C19.2, PHRBNL, bK150C2.2',
#  'APOBEC3C': 'A3C, APOBEC1L, ARDC2, ARDC4, ARP5, PBI, bK150C2.3',
#  'APOBEC3F': 'A3F, ARP8, BK150C2.4.MRNA, KA6',
#  'APOBEC3D': 'A3D, A3DEE, APOBEC3E, ARP6, APOBEC3D',
#  'APOBEC3G': 'A3G, ARCD, ARP-9, ARP9, CEM-15, CEM15, MDS019, bK150C2.7, dJ494G10.1',
#  'APOBEC3H': 'A3H, ARP-10, ARP10',
#  'PDGFB': 'IBGC5, PDGF-2, PDGF2, SIS, SSV, c-sis',
#  'RPL3': 'ASC-1, L3, TARBP-B',
#  'SNORD83B': 'RNU83B, U83B',
#  'SNORD83A': 'RNU83A, U83A',
#  'SNORD139': 'RNU86, U82, U86',
#  'SNORD43': 'RNU43, U43',
#  'TAB1': "3'-Tab1, MAP3K7IP1",
#  'MGAT3': 'GNT-III, GNT3',
#  'MGAT3-AS1': 'TapSAKI',
#  'MIEF1': 'AltMIEF1, HSU79252, MID51-MP, SMCR7L, dJ1104E15.3, MIEF1',
#  'ATF4': 'CREB-2, CREB2, TAXREB67, TXREB',
#  'RPS19BP1': 'AROS, S19BP',
#  'CACNA1I': 'Cav3.3, ca(v)3.3',
#  'ENTHD1': 'CACNA1I, dJ370M22.3',
#  'GRAP2': 'GADS, GRAP-2, GRB2L, GRBLG, GRID, GRPL, GrbX, Grf40, Mona, P38',
#  'TNRC6B': 'GDSBA',
#  'ADSL': 'AMPS, ASASE, ASL',
#  'SGSM3': 'CIP85, MAP, RABGAP5, RUSC3, RUTBC3, RabGAP-5, rabGAPLP',
#  'MRTFA': 'BSAC, MAL, MKL, MKL1, MRTF-A',
#  'MCHR1': 'GPR24, MCH-1R, MCH1R, SLC-1, SLC1',
#  'SLC25A17': 'PMP34',
#  'MIR4766': 'mir-4766',
#  'ST13': 'AAG2, FAM10A1, FAM10A4, HIP, HOP, HSPABP, HSPABP1, P48, PRO0786, SNC6',
#  'XPNPEP3': 'APP3, ICP55, NPHPL1',
#  'DNAJB7': 'DJ5, HSC3',
#  'RBX1': 'BA554C12.1, RNF75, ROC1',
#  'MIR1281': 'MIRN1281, hsa-mir-1281',
#  'EP300': 'KAT3B, MKHK2, RSTS2, p300',
#  'L3MBTL2': 'H-l(3)mbt-l, L3MBT',
#  'CHADL': 'SLRR4B',
#  'RANGAP1': 'Fug1, RANGAP, SD',
#  'MIR6889': 'hsa-mir-6889',
#  'ZC3H7B': 'ROXAN1, RoXaN',
#  'TOB2': 'APRO5, TOB4, TOBL, TROB2',
#  'PHF5A': 'INI, Rds3, SAP14b, SF3B7, SF3b14b, bK223H9.2',
#  'ACO2': 'ACONM, HEL-S-284, ICRD, OCA8, OPA9',
#  'POLR3H': 'C25, RPC22.9, RPC8',
#  'CSDC2': 'PIPPIN, dJ347H13.2',
#  'PMM1': 'PMM 1, PMMH-22, Sec53',
#  'DESI1': 'D15Wsu75e, DESI2, DJ347H13.4, DeSI-1, FAM152B, POST, PPPDE2',
#  'XRCC6': 'CTC75, CTCBF, G22P1, KU70, ML8, TLAA',
#  'SNU13': '15.5K, FA-1, FA1, NHP2L1, NHPX, OTK27, SNRNP15-5, SPAG12, SSFA1',
#  'MEI1': 'HYDM3, SPATA38',
#  'SREBF2-AS1': '821D11.7, RP5',
#  'SREBF2': 'SREBP-2, SREBP2, bHLHd2',
#  'MIR33A': 'MIR33, MIRN33, MIRN33A, hsa-mir-33, hsa-mir-33a, miR-33, miRNA33A, mir-33a',
#  'SHISA8': 'C22orf17, Orf26',
#  'TNFRSF13C': 'BAFF-R, BAFFR, BROMIX, CD268, CVID4, prolixin',
#  'CENPM': 'C22orf18, CENP-M, PANE1',
#  'SMIM45': 'BK250D10.8, LINC00634',
#  'SEPTIN3': 'SEP3, SEPT3, bK250D10.3',
#  'WBP2NL': 'GRAMD7, PAWP',
#  'NAGA': 'D22S674, GALB',
#  'PHETA2': 'FAM109B, IPIP27B, Ses2',
#  'SMDT1': 'C22orf32, DDDD, EMRE',
#  'NDUFA6': 'B14, CI-B14, LYRM6, MC1DN33, NADHB14',
#  'NDUFA6-DT': 'NDUFA6-AS1',
#  'CYP2D6': 'CPD6, CYP2D, CYP2D7AP, CYP2D7BP, CYP2D7P2, CYP2D8P2, CYP2DL1, CYPIID6, P450-DB1, P450C2D, P450DB1',
#  'CYP2D7': 'CYP2D, CYP2D6AP, CYP2D7P, CYP2D7P1, CYP2D@, P450C2D, P450DB1, RNA40057, CYP2D7',
#  'TCF20': 'AR1, DDVIBA, SPBP, TCF-20',
#  'LINC01315': 'C22orf32-1, lnc-C22orf32-1',
#  'NFAM1': 'CNAIP',
#  'SERHL': 'BK126B4.1',
#  'RRP7A': 'BK126B4.3, CGI-96, MCPH28, Rrp7',
#  'SERHL2': 'dJ222E13.1',
#  'RRP7BP': 'RRP7B, dJ222E13.2',
#  'POLDIP3': 'PDIP3, PDIP46, SKAR',
#  'RNU12': 'RNU12-1L, RNU12P, dJ222E13.7, RNU12',
#  'CYB5R3': 'B5R, DIA1',
#  'ATP5MGL': 'ATP5K2, ATP5L2',
#  'A4GALT': 'A14GALT1, Gb3S, P(k), P1, P1PK, PK, A4GALT',
#  'ARFGAP3': 'ARFGAP1',
#  'PACSIN2': 'SDPII',
#  'TTLL1': 'C22orf7, HS323M22B, TPGS3',
#  'BIK': 'BIP1, BP4, NBK',
#  'MCAT': 'FASN2C, MCT, MCT1, MT, NET62, fabD',
#  'TSPO': 'BPBS, BZRP, DBI, IBP, MBR, PBR, PBS, PKBS, PTBR, mDRC, pk18',
#  'TTLL12': 'dJ526I14.2',
#  'MPPED1': '239AB, C22orf1, FAM1A',
#  'EFCAB6': 'DJBP, HSCBCIP1, dJ185D5.1',
#  'SULT4A1': 'BR-STL-1, BRSTL1, DJ388M5.3, NST, SULTX3, hBR-STL-1',
#  'PNPLA5': 'GS2L, dJ388M5, dJ388M5.4',
#  'PNPLA3': 'ADPN, C22orf20, iPLA(2)epsilon',
#  'SAMM50': 'CGI-51, OMP85, SAM50, TOB55, TRG-3, YNL026W',
#  'PARVB': 'CGI-56',
#  'SHISAL1': 'KIAA1644',
#  'RTL6': 'LDOC1L, Mar6, Mart6, SIRH3, dJ1033E15.2',
#  'LINC00207': 'NCRNA00207',
#  'LINC00229': 'C22orf10, NCRNA00229, dJ474I12.C22.2',
#  'PRR5': 'FLJ20185k, PP610, PROTOR-1, PROTOR1',
#  'ARHGAP8': 'BPGAP1, PP610',
#  'PHF21B': 'BHC80L, PHF4',
#  'NUP50-DT': 'NUP50-AS1',
#  'NUP50': 'NPAP60, NPAP60L',
#  'KIAA0930': 'C22orf9, LSC3',
#  'MIR1249': 'MIRN1249, hsa-mir-1249',
#  'UPK3A': 'UP3A, UPIII, UPIIIA, UPK3',
#  'FAM118A': 'C22orf8',
#  'SMC1B': 'SMC1BETA, SMC1L2',
#  'RIBC2': 'C22orf11, TRIB',
#  'FBLN1': 'FBLN, FIBL1',
#  'LINC01589': 'TCONS_00029353',
#  'ATXN10': 'ATX10, E46L, HUMEEP, SCA10',
#  'LOC107985535': 'WI2-85898F10.1',
#  'PRR34': 'C22orf26',
#  'MIRLET7BHG': 'linc-Ppara',
#  'MIRLET7B': 'LET7B, MIRNLET7B, hsa-let-7b, let-7b',
#  'PPARA': 'NR1C1, PPAR, PPAR-alpha, PPARalpha, hPPAR',
#  'CDPF1': 'C22orf40',
#  'TTC38': 'LL22NC03-5H6.5',
#  'GTSE1': 'B99',
#  'GTSE1-DT': 'CN5H6.4, GTSE1-AS1, LL22NC03-5H6.6',
#  'TRMU': 'LCAL3, MTO2, MTU1, TRMT, TRMT1',
#  'CELSR1': 'ADGRC1, CDHF9, FMI2, HFMI2, LMPHM9, ME2',
#  'GRAMD4': 'DIP',
#  'CERK': 'LK4, dA59H18.2, dA59H18.3, hCERK',
#  'TBC1D22A': 'C22orf4, HSC79E021',
#  'LINC01644': 'LL22NC03-75H12.2',
#  'TAFA5': 'FAM19A5, QLLK5208, TAFA-5, UNQ5208',
#  'LINC01310': 'WI2-81516E3.1',
#  'MIR3667HG': 'C22orf34',
#  'BRD1': 'BRL, BRPF1, BRPF2',
#  'ALG12': 'CDG1G, ECM39, PP14673, hALG12',
#  'PIM3': 'pim-3',
#  'MIR6821': 'hsa-mir-6821',
#  'MLC1': 'LVM, MLC, VL',
#  'MOV10L1': 'CHAMP, DJ402G11.8',
#  'PANX2': 'PX2, hPANX2',
#  'TRABD': 'LP6054, PP2447',
#  'SELENOO': 'SELO',
#  'TUBGCP6': 'GCP-6, GCP6, MCCRP, MCCRP1, MCPHCR',
#  'HDAC10': 'HD10',
#  'MAPK12': 'ERK-6, ERK3, ERK6, MAPK 12, P38GAMMA, PRKM12, SAPK-3, SAPK3',
#  'MAPK11': 'P38B, P38BETA2, PRKM11, SAPK2, SAPK2B, p38-2, p38Beta',
#  'PLXNB2': 'MM1, Nbla00445, PLEXB2, dJ402G11.3',
#  'DENND6B': 'AFI1B, FAM116B',
#  'PPP6R2': 'KIAA0685, PP6R2, SAP190, SAPS2',
#  'SBF1': 'CMT4B3, DENND7A, MTMR5',
#  'ADM2': 'AM2, dJ579N16.4',
#  'MIOX': 'ALDRL6',
#  'LMF2': 'TMEM112B, TMEM153',
#  'NCAPH2': 'CAPH2',
#  'SCO2': 'CEMCOX1, ECGF1, Gliostatin, MC4DN2, MYP6, PD-ECGF, SCO1L, TP, TYMP, TdRPase',
#  'TYMP': 'ECGF, ECGF1, MEDPS1, MNGIE, MTDPS1, PDECGF, TP, hPD-ECGF',
#  'ODF3B': 'ODF3L3',
#  'SYCE3': 'C22orf41, THEG2',
#  'CPT1B': 'CPT1-M, CPT1M, CPTI, CPTI-M, M-CPT1, MCCPT1, MCPT1',
#  'CHKB-CPT1B': 'CHKL-CPT1B, CPT1-M, CPT1B, CPTI-M',
#  'CHKB': 'CHETK, CHKL, CK, CKB, CKEKB, EK, EKB, MDCMC',
#  'CHKB-DT': 'CHKB-AS1',
#  'MAPK8IP2': 'IB-2, IB2, JIP2, PRKM8IPL',
#  'ARSA': 'ASA, MLD',
#  'SHANK3': 'DEL22q13.3, PROSAP2, PSAP2, SCZD15, SPANK-2',
#  'RPL23AP82': 'RPL23A_43_1761'}

# %% [markdown]
# # Saving dictionary to json file:

# %%
with open('Data/gene_aliases.json', 'w') as f:
    json.dump(gene_alias_dict, f)

# %% [markdown]
# - A dictionary is saved so that it can be loaded and searched through in the case a user submits a query with a gene name that doesn't match the one's stored in column GENE1 or GENE2 in our data.

# %% [markdown]
# # Example of Code in Web-App:
# - Below is an example of how this code would run within the web-app.

# %%
def load_json(filename):
    with open(filename) as f_in:
        return json.load(f_in)

# %%
def get_key(val, gene_dict):
    for key, value in gene_dict.items():
        if val in value:
            return key
        else:
            pass

# %%
# Loading dictionary:
trial_dict = load_json('Data/gene_aliases.json')

# %%
# Getting the key (the name in our data), when user submits an alias:
get_key('AIFL', trial_dict)
# Out:
# 'AIFM3'

# %%
# Get key where gene name is not in database:
trial = get_key('ROFL', trial_dict)

# %%
trial == None
# Out:
# True
